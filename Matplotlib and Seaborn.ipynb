# %% [markdown]
# ![Screenshot%202023-09-22%20at%209.36.03%20AM.png](attachment:Screenshot%202023-09-22%20at%209.36.03%20AM.png)

# %% [markdown]
# ![Screenshot%202023-09-22%20at%204.29.50%20PM.png](attachment:Screenshot%202023-09-22%20at%204.29.50%20PM.png)

# %%
#Example Questions:
#1.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import seaborn as sns

# %%
style.use("ggplot")

# %%
values = np.random.rand(10)
plt.figure(figsize = (8,3))
plt.plot(values,'g', label = "Random data", linewidth = 2, linestyle = "--")
plt.title("Random data line chart")
plt.xlabel("X")
plt.ylabel("Values")
plt.legend()
plt.show()

# %%
#2.
x = list(range(0,10))
y = np.random.rand(10)
plt.figure(figsize = (4,4))
plt.scatter(x,y, linewidths = 4)
plt.title("Scatter plot of random data")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
#3.
#df = pd.read_csv("mtcars.csv")
#df
#sns.barplot(data = df, x = "cyl")
#plt.bar(x = df["cyl"], height = df["cyl"])
#plt.show()
#print(df.cyl.value_counts())

#sns.countplot(data = df, x = "cyl")

# %%
#Practice Questions:
#1.
df = pd.read_csv("mtcars.csv")
plt.figure(figsize = (8,4))
plt.plot(df['mpg'],label = "Mpg")
plt.title("Line chart of Mpg over indexs in the data set")
plt.xlabel("Indexes of dataset")
plt.ylabel("Mpg of the car")
plt.legend()
plt.show()

# %%
#2.
df = pd.read_csv("mtcars.csv")
df.head()
plt.figure(figsize = (6,3))
plt.hist(df['disp'],label = "Displacement", bins = 15, color = 'green')
plt.title("Distribution of displacement")
plt.xlabel("Displacement")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# %%
#3.
df = pd.read_csv("mtcars.csv")
df.head()
plt.figure(figsize = (4,4))
sns.scatterplot(data = df, x ='cyl', y ='carb')
plt.title("Scatter plot cylinder vs carb")
plt.xlabel("Cylinder")
plt.ylabel("Carb")
plt.show()

# %%
#4.
df = pd.read_csv("mtcars.csv")
df.head()
plt.figure(figsize = (4,4))
for i in df.iloc[:,1:11].columns:
    plt.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
df = pd.read_csv("mtcars.csv")
df.head()
plt.figure(figsize = (7,4))
sns.barplot(data = df, x ='cyl', y ='disp')
plt.title("Bar plot cylinder vs displacement")
plt.xlabel("Cylinder")
plt.ylabel("Displacement")
plt.show()

# %%
#6.
df = pd.read_csv("mtcars.csv")
df.head()
plt.figure(figsize = (6,5))
sns.violinplot(data = df, x ='cyl', y ='disp')
plt.title("Violenplot cylinder vs displacement")
plt.xlabel("Cylinder")
plt.ylabel("Displacement")
plt.show()

# %%
#7.
df = pd.read_csv("mtcars.csv")
df.head()
plt.figure(figsize = (6,6))
sns.pairplot(data = df, x_vars = 'disp', y_vars ='hp', kind = 'reg')
plt.title("Violenplot cylinder vs displacement")
plt.xlabel("Cylinder")
plt.ylabel("Displacement")
plt.show()

# %%
(df["cyl"].value_counts())
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
#8.
df = pd.read_csv("mtcars.csv")
#df.head()
plt.figure(figsize = (6,6))
plt.pie(x = df["cyl"].value_counts(),labels = [4,6,8], explode = [0.1,0.08,0.05], autopct = "%1.1f%%")
plt.title("Pie Chart of number of cylinders in the data set")
plt.show()

# %%
#9.
df = pd.read_csv("mtcars.csv")
df.head()
sns.swarmplot(data = df, x = "cyl", y = "disp")
# Out:
# <Axes: xlabel='cyl', ylabel='disp'>

# %%
#10.
df = pd.read_csv("mtcars.csv")
corr = df.iloc[:,1:11].corr()
plt.figure(figsize = (8,8))
sns.heatmap(data = corr, annot = True, square = True)
# Out:
# <Axes: >
